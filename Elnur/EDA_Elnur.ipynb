# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas

# %%
df_json = pd.read_json('london.json')

# %%
df_json.head(5)
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...

# %%
df_geo = geopandas.read_file('london.json')
df_geo.head(5)
# Out:
#    msoa_code       msoa_name la_code     la_name  geoeast  geonorth  popeast  \
# 0  E02000508  Hillingdon 015    00AS  Hillingdon   506163    183536   505978
# 1  E02000716      Newham 003    00BB      Newham   541978    186009   541870
# 2  E02000747      Newham 034    00BB      Newham   539578    181317   539891
# 3  E02000748      Newham 035    00BB      Newham   542500    181152   542439
# 4  E02000749      Newham 036    00BB      Newham   541047    181103   540847
#
#    popnorth  area_km2 MOVEMENT_ID          DISPLAY_NAME  \
# 0    183811   2.74660           0  Hillingdon, 00AS (0)
# 1    185568   1.56517           1      Newham, 00BB (1)
# 2    181438   2.08241           2      Newham, 00BB (2)
# 3    181339   1.33175           3      Newham, 00BB (3)
# 4    181294   1.41902           4      Newham, 00BB (4)
#
#                                             geometry
# 0  MULTIPOLYGON (((-0.47794 51.55485, -0.47665 51...
# 1  MULTIPOLYGON (((0.05255 51.56171, 0.05310 51.5...
# ...

# %%
df_geo.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('training_WeeklyAggregate.csv')
df.head()
# Out:
#    sourceid  dstid  dow  mean_travel_time
# 0        10    241    3           2334.43
# 1        10    612    5           1529.83
# 2        10    905    4           1390.04
# 3        10    407    7            157.91
# 4        10    603    4           1781.67

# %%
import pandas_profiling as pp
# pp.profile_report(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7980/3632390405.py in <module>
# ----> 1 import pandas_profiling as pp
#       2 # pp.profile_report(df)
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22772/3886088315.py in <module>
# ----> 1 import pandas_profiling
#
# D:\anaconda\envs\pandas_profiling\lib\site-packages\pandas_profiling\__init__.py in <module>
#       5
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# D:\anaconda\envs\pandas_profiling\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.__init__ import ProfileReport
#       5
#       6
#
# D:\anaconda\envs\pandas_profiling\lib\site-packages\pandas_profiling\__init__.py in <module>
# ...
